# %%
#wivr gazp imuc yprx
import smtplib
import getpass
import ssl
from email.message import EmailMessage
host='smtp.gmail.com'
port=465
sender_email = "chetanavasave34@gmail.com"
sender_password = "wivr gazp imuc yprx"
to_email="vasavechetana5@gmail.com"
context=ssl.create_default_context()

# password=getpass.getpass('Enter password:')
em=EmailMessage()
em['From']=sender_email
em['To']=to_email
em['subject']="testing email smtp"

msg="Hi"
with smtplib.SMTP_SSL(host,465,context=context) as smtp:
    smtp.login(sender_email,sender_password)
    smtp.sendmail(sender_email,to_email,em.as_string())
# server = smtplib.SMTP(host,port)

# server.quit()

# %%
import pandas as pd
import smtplib
import getpass
# from email.mime.text import MIMEText
# from email.mime.multipart import MIMEMultipart

# Load student data
data = pd.read_excel(r"absent_students_data.xlsx")   # Ensure it has columns like 'Name', 'Email', 'Topics'
data
# Email credentials
sender_email = "chetanavasave07@gmail.com"
sender_password = "chetana123@"

# # SMTP setup
server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender_email, sender_password)

for index, row in data.iterrows():
    # Create email
    receiver_email = row['Email Id']
    name = row['Name']
    topic = row['Todays Topic']
    # print(receiver_email)
    # print(name)
    # print(topic)
    
    message = MIMEMultipart()
    message['From'] = sender_email
    message['To'] = receiver_email
    message['Subject'] = "Attendance Notification"

    # # Personalize the email content
    # email_body = f"""
    # Dear {name},

    # You were absent today. Topics covered:
    # {topics}

    # Please ensure you review the materials to catch up.
    # Regards,
    # Your Institute
    # """
    # message.attach(MIMEText(email_body, 'plain'))

    # # Send email
    # server.sendmail(sender_email, receiver_email, message.as_string())

# server.quit()
# print("Emails sent successfully!")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[23], line 16
#      14 server = smtplib.SMTP('smtp.gmail.com', 587)
#      15 server.starttls()
# ---> 16 server.login(sender_email, sender_password)
#      18 for index, row in data.iterrows():
#      19     # Create email
#      20     receiver_email = row['Email Id']
#
# File ~\anaconda3\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\anaconda3\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
# ...

# %%
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Load student data
data = pd.read_excel(r"absent_students.xlsx")   # Ensure it has columns like 'Name', 'Email', 'Topics'

# Email credentials
sender_email = "chetanavasave07@gmail.com"
sender_password = "Chetana123@"

# SMTP setup
server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender_email, sender_password)

for index, row in data.iterrows():
    # Create email
    receiver_email = row['Email']
    name = row['Name']
    topics = row['Topics']
    
    message = MIMEMultipart()
    message['From'] = sender_email
    message['To'] = receiver_email
    message['Subject'] = "Attendance Notification"

    # Personalize the email content
    email_body = f"""
    Dear {name},

    You were absent today. Topics covered:
    {topics}

    Please ensure you review the materials to catch up.
    Regards,
    Your Institute
    """
    message.attach(MIMEText(email_body, 'plain'))

    # Send email
    server.sendmail(sender_email, receiver_email, message.as_string())

server.quit()
print("Emails sent successfully!")
